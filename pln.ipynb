# %%
#librerias con la que se esta trabajando
import numpy as np
import tweepy
from textblob import TextBlob
import csv
import re
import sys
import pandas as pd
import matplotlib.pyplot as plt

# %%
#se esta cargando los key, para la conexion con el dataset en ete caso de twitter
consumer_key = "NJl34FdbXH3e0PsLSPkmjDaxd"
consumer_secret = "UY44nc4Pz01XZvKrLJMobACvVO53OOEI4cNgUQQL3CqsosoC6s"
access_token_key = "71717892-XTCj9GQZK3ISPJKBeLSJcsIDjRJsMEbJB0peQKaGd"
access_token_secret = "gJafimc353DVkESj1o0dlxvhAD3rmF7deNoAvme6gpqUp"

# %%
#se realiza loq eues el cargado de las claves de acceeso a twitter
auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token_key,access_token_secret)

# %%
#se crea una isntancia en donde se vaa buscar los twitts, para ser analizados, en este caso de concytecPeru
api=tweepy.API(auth)
topicname='natural language processing'


#loq eu se hace es el cargado de la data la cual mediante un api se busca segun a el paralemtro asignado
pubic_tweets=api.search(topicname, count=20)

# %%
#se declaran lo que es variables qeu se van a excluir, ya sean algunas palabras o simbolos
unwanted_words=['@','RT',':','https','http']
symbols=['@','#']
data=[]

# %%
# este for loq eu realiza es el recorrido de los twitts para analisarlos uno por uno y mostrr sus resultados correspondentes
cont = 0
polarity=[]
subj=[]
for tweet in pubic_tweets:
    text=tweet.text
    textWords=text.split()
    cont=cont+1
    print(cont)
    print (textWords)
    print("")
    cleanedTweet=' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|(RT)", " ", text).split())
    print("texto extraido:")
    print (cleanedTweet)
    
    # lo que se esta realizando es el analisis con la funcion TextBlob que este muuestra el sentimiento y cuan subjetividad es
    # y de acuerdo a la polaridad muestra lo que es la polaridad si es considerado un mensaje positivo, negativo o neutro
    
    analysis= TextBlob(cleanedTweet)
    
 
    print("")
    print (analysis.sentiment)
    if(analysis.sentiment.polarity > 0.2):
        polarity = 'Positive'
    if(analysis.sentiment.polarity < 0):
        polarity = 'Negative'
    if(0<=analysis.sentiment.polarity <=0.2):
        polarity = 'Neutral'
    print (polarity)
    print("..................................................................")
    
    # loq ue se esta realizando es: juntar todos los resultados para posteriormente guardarlo en un csv.
    
    dic={}
    dic['Sentiment']=polarity
    dic['Tweet']=cleanedTweet
    data.append(dic)
# Out:
# 1
# ['Assistant', 'Professor', 'with', 'emphasis', 'on', 'Natural', 'Language', 'Processing', 'https://t.co/D3szBQq4hX', 'https://t.co/Eoc9G3tiDk']
#
# texto extraido:
# Assistant Professor with emphasis on Natural Language Processing
#
# Sentiment(polarity=0.1, subjectivity=0.4)
# Neutral
# ..................................................................
# 2
# ['International', 'Conference', 'on', 'Natural', 'Language', 'Processing', 'and', 'Machine', 'Learning', '(NLPML', '2020)', 'https://t.co/HFP1VF8dzf']
#
# texto extraido:
# International Conference on Natural Language Processing and Machine Learning NLPML 2020
#
# Sentiment(polarity=0.05, subjectivity=0.2)
# Neutral
# ..................................................................
# 3
# ['RT', '@WalmartTech:', 'Our', '#WalmartTechDFW', 'associate', 'Zahra', 'gave', 'an', 'excellent', 'talk', 'on', 'natural', 'language', 'processing', 'to', 'a', 'packed', 'house', 'at', 'the', 'Texas', 'A…']
#
# texto extraido:
# Our WalmartTechDFW associate Zahra gave an excellent talk on natural language processing to a packed house at the Texas A
#
# Sentiment(polarity=0.55, subjectivity=0.7)
# Positive
# ..................................................................
# 4
# ['Grammarly', 'AI:', 'The', 'sweet', 'spot', 'of', 'deep', 'learning', 'and', 'natural', 'language', 'processing', '–', 'TechTalks', 'https://t.co/OPyGXegpXi']
#
# texto extraido:
# Grammarly AI The sweet spot of deep learning and natural language processing TechTalks
#
# Sentiment(polarity=0.15, subjectivity=0.4833333333333334)
# Neutral
# ..................................................................
# 5
# ['RT', '@supermadujackie:', 'Artificial', 'Intelligence', 'is', 'already', 'transforming', 'the', 'ways', 'customers', '&amp;', 'business', 'interact', 'with', 'each', 'other', 'and', 'at', 'the', 'core…']
#
# texto extraido:
# Artificial Intelligence is already transforming the ways customers amp business interact with each other and at the core
#
# Sentiment(polarity=-0.3625, subjectivity=0.6875)
# Negative
# ..................................................................
# 6
# ['RT', '@supermadujackie:', 'Artificial', 'Intelligence', 'is', 'already', 'transforming', 'the', 'ways', 'customers', '&amp;', 'business', 'interact', 'with', 'each', 'other', 'and', 'at', 'the', 'core…']
#
# texto extraido:
# Artificial Intelligence is already transforming the ways customers amp business interact with each other and at the core
#
# Sentiment(polarity=-0.3625, subjectivity=0.6875)
# Negative
# ..................................................................
# 7
# ['RT', '@supermadujackie:', 'Artificial', 'Intelligence', 'is', 'already', 'transforming', 'the', 'ways', 'customers', '&amp;', 'business', 'interact', 'with', 'each', 'other', 'and', 'at', 'the', 'core…']
#
# texto extraido:
# Artificial Intelligence is already transforming the ways customers amp business interact with each other and at the core
#
# Sentiment(polarity=-0.3625, subjectivity=0.6875)
# Negative
# ..................................................................
# 8
# ['RT', '@msdev_be:', "You're", 'using', 'LUIS', 'to', 'add', 'natural', 'language', 'processing', '(#NLP)', 'to', 'your', 'application.', 'But', 'how', 'do', 'you', 'measure', 'the', 'performance', 'of', 'yo…']
#
# texto extraido:
# be You re using LUIS to add natural language processing NLP to your application But how do you measure the performance of yo
#
# Sentiment(polarity=0.1, subjectivity=0.4)
# Neutral
# ..................................................................
# 9
# ['Assistant', 'Professor', 'with', 'emphasis', 'on', 'Natural', 'Language', 'Processing', 'https://t.co/2OwAHskdWD', 'https://t.co/MWGYFvsqop']
#
# texto extraido:
# Assistant Professor with emphasis on Natural Language Processing
#
# Sentiment(polarity=0.1, subjectivity=0.4)
# Neutral
# ..................................................................
# 10
# ['RT', '@DD_FaFa_:', 'Grammarly', 'AI:', 'The', 'sweet', 'spot', 'of', 'deep', 'learning', 'and', 'natural', 'language', 'processing', 'https://t.co/Fakpv7Z5L7']
#
# texto extraido:
# FaFa Grammarly AI The sweet spot of deep learning and natural language processing
#
# Sentiment(polarity=0.15, subjectivity=0.4833333333333334)
# Neutral
# ..................................................................
# 11
# ['ProICT', 'Training', 'offers', 'one', 'of', 'the', 'best', 'online', 'Natural', 'Language', 'Processing', '(NLP)', 'training', '&amp;', 'certification', 'course.', 'Ta…', 'https://t.co/3XxwFJudwc']
#
# texto extraido:
# ProICT Training offers one of the best online Natural Language Processing NLP training amp certification course Ta
#
# Sentiment(polarity=0.4000000000000001, subjectivity=0.2333333333333333)
# Positive
# ..................................................................
# 12
# ['RT', '@googlecloud:', '"@easyJet', 'is', 'using', 'the', '@GCPcloud’s', 'natural', 'language', 'processing', 'technology', 'to', 'enable', 'customers', 'to', 'search', 'for', 'flight', 'informa…']
#
# texto extraido:
# is using the s natural language processing technology to enable customers to search for flight informa
#
# Sentiment(polarity=0.1, subjectivity=0.4)
# Neutral
# ..................................................................
# 13
# ['Neil', 'Garner', 'and', 'AI:', '3', 'major', 'elements:', 'planning,', 'Natural', 'Language', 'Processing', 'and', 'Reasoning', '▶️', 'Machine', 'Learning…', 'https://t.co/EpjM8IoyE7']
#
# texto extraido:
# Neil Garner and AI 3 major elements planning Natural Language Processing and Reasoning Machine Learning
#
# Sentiment(polarity=0.08125, subjectivity=0.45)
# Neutral
# ..................................................................
# 14
# ['Grammarly', 'AI:', 'The', 'sweet', 'spot', 'of', 'deep', 'learning', 'and', 'natural', 'language', 'processing', 'https://t.co/Fakpv7Z5L7']
#
# texto extraido:
# Grammarly AI The sweet spot of deep learning and natural language processing
#
# Sentiment(polarity=0.15, subjectivity=0.4833333333333334)
# Neutral
# ..................................................................
# 15
# ['RT', '@DataScienceCtrl:', '11', 'Great', 'Articles', 'About', 'Natural', 'Language', 'Processing', '(NLP)', 'https://t.co/FS7uLqjkFt']
#
# texto extraido:
# 11 Great Articles About Natural Language Processing NLP
#
# Sentiment(polarity=0.45, subjectivity=0.575)
# Positive
# ..................................................................
# 16
# ['RT', '@Datascience__:', 'Deep', 'Learning', 'for', 'Natural', 'Language', 'Processing:', 'Solve', 'your', 'natural', 'language', 'processing', 'problems', 'with', 'smart', 'deep', 'neural', 'ne…']
#
# texto extraido:
# Deep Learning for Natural Language Processing Solve your natural language processing problems with smart deep neural ne
#
# Sentiment(polarity=0.08285714285714285, subjectivity=0.44857142857142857)
# Neutral
# ..................................................................
# 17
# ['New', 'advances', 'in', 'natural', 'language', 'processing', 'to', 'better', 'connect', 'people', 'https://t.co/MCHLDNeNZf']
#
# texto extraido:
# New advances in natural language processing to better connect people
#
# Sentiment(polarity=0.24545454545454545, subjectivity=0.4515151515151515)
# Positive
# ..................................................................
# 18
# ['RT', '@supermadujackie:', 'Artificial', 'Intelligence', 'is', 'already', 'transforming', 'the', 'ways', 'customers', '&amp;', 'business', 'interact', 'with', 'each', 'other', 'and', 'at', 'the', 'core…']
#
# texto extraido:
# Artificial Intelligence is already transforming the ways customers amp business interact with each other and at the core
#
# Sentiment(polarity=-0.3625, subjectivity=0.6875)
# Negative
# ..................................................................
# 19
# ['Natural', 'Language', 'Processing', 'With', 'spaCy', 'in', 'Python', '–', 'Real', 'Python', 'https://t.co/ZFR6MSEFl1']
#
# texto extraido:
# Natural Language Processing With spaCy in Python Real Python
#
# Sentiment(polarity=0.15000000000000002, subjectivity=0.35000000000000003)
# Neutral
# ..................................................................
# 20
# ['RT', '@LionbridgeAI:', 'Training', 'successful', '#MachineLearning', 'algorithms', 'requires', 'lots', 'of', 'data,', 'but', 'how', 'much?', 'https://t.co/cV8Zxe5LjP']
#
# texto extraido:
# Training successful MachineLearning algorithms requires lots of data but how much
#
# Sentiment(polarity=0.475, subjectivity=0.575)
# Positive
# ..................................................................

# %%
# se hace una copia de respaldodo de todos los resultados
df.to_csv('analysis1.csv')
